# %% [markdown]
# ### Runtime & environment

# %%
# !pip -q install py7zr
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.7/69.7 kB 2.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 39.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.4/96.4 kB 5.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 3.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.3/141.3 kB 8.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 412.9/412.9 kB 21.1 MB/s eta 0:00:00

# %% [markdown]
# ### Imports, config, seeds, class names

# %%
import os, math, glob, numpy as np, tensorflow as tf, pandas as pd
from tensorflow import keras
from tensorflow.keras import layers

# Reproducibility & performance
SEED = 1337
tf.keras.utils.set_random_seed(SEED)
AUTO = tf.data.AUTOTUNE
tf.config.optimizer.set_jit(False) 

# Hyperparameters
BATCH_TRAIN = 64
BATCH_TEST  = 64
EPOCHS      = 100
LR          = 1e-2
MOMENTUM    = 0.9
WEIGHT_DECAY = 1e-6  # L2 via kernel_regularizer
NUM_CLASSES = 10
CLASS_NAMES = ['airplane','automobile','bird','cat','deer','dog','frog','horse','ship','truck']
# Out:
# 2025-09-19 18:08:23.367624: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1758305303.709203      19 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1758305303.801447      19 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %% [markdown]
# ### Loads official CIFAR-10 (train/test) via Keras

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.cifar10.load_data()
y_train = keras.utils.to_categorical(y_train, NUM_CLASSES)
y_test  = keras.utils.to_categorical(y_test,  NUM_CLASSES)

print(x_train.shape, y_train.shape, x_test.shape, y_test.shape)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step
# (50000, 32, 32, 3) (50000, 10) (10000, 32, 32, 3) (10000, 10)

# %% [markdown]
# ### Augmentations & tf.data pipelines

# %%
train_aug = keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomTranslation(0.05, 0.05, fill_mode="reflect"),
    layers.RandomZoom(0.05, 0.05, fill_mode="reflect"),
    layers.RandomContrast(0.1),
    layers.RandomBrightness(0.1),
])

def preprocess(x, y=None):
    x = tf.cast(x, tf.float32) / 255.0
    return (x, y) if y is not None else x

def make_ds(x, y, train=False, batch=100):
    ds = tf.data.Dataset.from_tensor_slices((x, y))
    if train:
        ds = ds.shuffle(10000, seed=SEED, reshuffle_each_iteration=True)
        ds = ds.map(lambda a,b: (train_aug(a), b), num_parallel_calls=AUTO)
    ds = ds.map(lambda a,b: (preprocess(a), b), num_parallel_calls=AUTO)
    ds = ds.batch(batch).prefetch(AUTO)
    return ds

train_ds = make_ds(x_train, y_train, train=True,  batch=BATCH_TRAIN)
test_ds  = make_ds(x_test,  y_test,  train=False, batch=BATCH_TEST)  # used as validation proxy for Kaggle
# Out:
# I0000 00:00:1758305329.706589      19 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1758305329.707314      19 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5

# %% [markdown]
# ### Cutout

# %%
USE_CUTOUT = False  # set True for a small boost

def cutout(img, length=8):
    H = tf.shape(img)[0]; W = tf.shape(img)[1]
    y = tf.random.uniform([], 0, H, dtype=tf.int32)
    x = tf.random.uniform([], 0, W, dtype=tf.int32)
    y1 = tf.clip_by_value(y - length//2, 0, H); y2 = tf.clip_by_value(y + length//2, 0, H)
    x1 = tf.clip_by_value(x - length//2, 0, W); x2 = tf.clip_by_value(x + length//2, 0, W)
    mask = tf.ones([y2-y1, x2-x1, 3], dtype=img.dtype)
    paddings = [[y1, H - y2], [x1, W - x2], [0, 0]]
    mask = tf.pad(mask, paddings, constant_values=0)
    return img * (1 - mask)

if USE_CUTOUT:
    def _train_map(a, b):
        a = cutout(a, length=8)
        return a, b
    train_ds = train_ds.map(_train_map, num_parallel_calls=AUTO).prefetch(AUTO)

# %% [markdown]
# ### Advanced CNN

# %%
L2 = keras.regularizers.l2(WEIGHT_DECAY)

def conv_bn_relu(x, filters, k=3, bn=False):
    x = layers.Conv2D(filters, k, padding="same", use_bias=not bn,
                      kernel_regularizer=L2)(x)
    if bn:
        x = layers.BatchNormalization()(x)
    return layers.ReLU()(x)

inputs = keras.Input(shape=(32, 32, 3))
x = inputs

# Block 1: 3 convs -> MaxPool
x = conv_bn_relu(x, 64*2, bn=True)   # conv1 + BN
x = conv_bn_relu(x, 64*2)            # conv2
x = conv_bn_relu(x, 64*2)            # conv3
x = layers.MaxPooling2D(2)(x)

# Block 2: 3 convs -> MaxPool -> Dropout
x = conv_bn_relu(x, 128*2, bn=True)  # conv4 + BN
x = conv_bn_relu(x, 128*2)           # conv5
x = conv_bn_relu(x, 128*2)           # conv6
x = layers.MaxPooling2D(2)(x)
x = layers.Dropout(0.2)(x)

# Block 3: 3 convs -> MaxPool -> Dropout
x = conv_bn_relu(x, 256*2, bn=True)  # conv7 + BN
x = conv_bn_relu(x, 256*2)           # conv8
x = conv_bn_relu(x, 256*2)           # conv9
x = layers.MaxPooling2D(2)(x)
x = layers.Dropout(0.2)(x)

# Classifier: 4*4*512 = 8192 -> 8192 -> 4096 -> 10
x = layers.Flatten()(x)
x = layers.Dense(4096*2, activation="relu", kernel_regularizer=L2)(x)
x = layers.Dense(2048*2, activation="relu", kernel_regularizer=L2)(x)
x = layers.Dropout(0.2)(x)
outputs = layers.Dense(NUM_CLASSES, activation="softmax")(x)

model = keras.Model(inputs, outputs)
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 32, 32, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 32, 32, 128)    │         3,456 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 32, 32, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu (ReLU)                    │ (None, 32, 32, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 32, 32, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_1 (ReLU)                  │ (None, 32, 32, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 32, 32, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_2 (ReLU)                  │ (None, 32, 32, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 16, 16, 256)    │       294,912 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 16, 16, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_3 (ReLU)                  │ (None, 16, 16, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 16, 16, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_4 (ReLU)                  │ (None, 16, 16, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 16, 16, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_5 (ReLU)                  │ (None, 16, 16, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 8, 8, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 8, 8, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 8, 8, 512)      │     1,179,648 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 8, 8, 512)      │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_6 (ReLU)                  │ (None, 8, 8, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 8, 8, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_7 (ReLU)                  │ (None, 8, 8, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (None, 8, 8, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_8 (ReLU)                  │ (None, 8, 8, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 4, 4, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 4, 4, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 8192)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 8192)           │    67,117,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4096)           │    33,558,528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 4096)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 10)             │        40,970 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 108,393,098 (413.49 MB)
#  Trainable params: 108,391,306 (413.48 MB)
#  Non-trainable params: 1,792 (7.00 KB)

# %% [markdown]
# ### Optimizer & compile (SGD + momentum)

# %%
opt = keras.optimizers.SGD(learning_rate=LR, momentum=MOMENTUM, nesterov=False)

model.compile(
    optimizer=opt,
    loss=keras.losses.CategoricalCrossentropy(label_smoothing=0.0),
    metrics=["accuracy"]
)

# %% [markdown]
# ### Callbacks

# %%
ckpt = keras.callbacks.ModelCheckpoint(
    filepath="adv_best.weights.h5",
    monitor="val_accuracy",
    save_best_only=True,
    save_weights_only=True,
)
plateau = keras.callbacks.ReduceLROnPlateau(
    monitor="val_loss", factor=0.1, patience=10, min_lr=1e-5, verbose=1
)
es = keras.callbacks.EarlyStopping(
    monitor="val_accuracy", patience=20, restore_best_weights=True
)
log = keras.callbacks.CSVLogger("adv_training_log.csv")

# %% [markdown]
# ### Train

# %%
history = model.fit(
    train_ds,
    validation_data=test_ds,
    epochs=EPOCHS,
    callbacks=[ckpt, plateau, es, log]
)
print("Final val_acc (official test):", round(float(history.history["val_accuracy"][-1]), 4))
# Out:
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1758305338.021077      73 service.cc:148] XLA service 0x7a580c005270 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1758305338.022913      73 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1758305338.022935      73 service.cc:156]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1758305338.646138      73 cuda_dnn.cc:529] Loaded cuDNN version 90300
#   1/782 ━━━━━━━━━━━━━━━━━━━━ 3:34:58 17s/step - accuracy: 0.1250 - loss: 2.4823
# I0000 00:00:1758305350.046168      73 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 132s 148ms/step - accuracy: 0.3639 - loss: 1.7466 - val_accuracy: 0.5449 - val_loss: 1.3814 - learning_rate: 0.0100
# Epoch 2/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 102s 131ms/step - accuracy: 0.6222 - loss: 1.0737 - val_accuracy: 0.4842 - val_loss: 1.8431 - learning_rate: 0.0100
# Epoch 3/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 107s 136ms/step - accuracy: 0.7187 - loss: 0.8145 - val_accuracy: 0.7335 - val_loss: 0.8005 - learning_rate: 0.0100
# Epoch 4/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 106s 135ms/step - accuracy: 0.7727 - loss: 0.6687 - val_accuracy: 0.7609 - val_loss: 0.7205 - learning_rate: 0.0100
# Epoch 5/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 106s 135ms/step - accuracy: 0.7969 - loss: 0.5965 - val_accuracy: 0.7695 - val_loss: 0.7171 - learning_rate: 0.0100
# Epoch 6/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 106s 136ms/step - accuracy: 0.8235 - loss: 0.5185 - val_accuracy: 0.8045 - val_loss: 0.5973 - learning_rate: 0.0100
# Epoch 7/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 102s 131ms/step - accuracy: 0.8470 - loss: 0.4624 - val_accuracy: 0.7963 - val_loss: 0.6310 - learning_rate: 0.0100
# Epoch 8/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 105s 135ms/step - accuracy: 0.8624 - loss: 0.4106 - val_accuracy: 0.8111 - val_loss: 0.5955 - learning_rate: 0.0100
# Epoch 9/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 106s 136ms/step - accuracy: 0.8738 - loss: 0.3800 - val_accuracy: 0.8320 - val_loss: 0.5471 - learning_rate: 0.0100
# Epoch 10/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 106s 135ms/step - accuracy: 0.8858 - loss: 0.3447 - val_accuracy: 0.8345 - val_loss: 0.5305 - learning_rate: 0.0100
# Epoch 11/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 106s 135ms/step - accuracy: 0.8979 - loss: 0.3169 - val_accuracy: 0.8437 - val_loss: 0.4992 - learning_rate: 0.0100
# Epoch 12/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 106s 135ms/step - accuracy: 0.9058 - loss: 0.2880 - val_accuracy: 0.8483 - val_loss: 0.4825 - learning_rate: 0.0100
# Epoch 13/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 106s 135ms/step - accuracy: 0.9159 - loss: 0.2606 - val_accuracy: 0.8612 - val_loss: 0.4761 - learning_rate: 0.0100
# Epoch 14/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 102s 130ms/step - accuracy: 0.9196 - loss: 0.2442 - val_accuracy: 0.8523 - val_loss: 0.4906 - learning_rate: 0.0100
# Epoch 15/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 102s 131ms/step - accuracy: 0.9310 - loss: 0.2160 - val_accuracy: 0.8481 - val_loss: 0.5188 - learning_rate: 0.0100
# Epoch 16/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 102s 130ms/step - accuracy: 0.9361 - loss: 0.2013 - val_accuracy: 0.8412 - val_loss: 0.5816 - learning_rate: 0.0100
# Epoch 17/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 106s 136ms/step - accuracy: 0.9414 - loss: 0.1863 - val_accuracy: 0.8646 - val_loss: 0.4661 - learning_rate: 0.0100
# Epoch 18/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 106s 135ms/step - accuracy: 0.9448 - loss: 0.1770 - val_accuracy: 0.8688 - val_loss: 0.4457 - learning_rate: 0.0100
# Epoch 19/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 102s 130ms/step - accuracy: 0.9497 - loss: 0.1623 - val_accuracy: 0.8582 - val_loss: 0.5130 - learning_rate: 0.0100
# Epoch 20/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 102s 130ms/step - accuracy: 0.9561 - loss: 0.1477 - val_accuracy: 0.8485 - val_loss: 0.5935 - learning_rate: 0.0100
# Epoch 21/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 105s 135ms/step - accuracy: 0.9558 - loss: 0.1427 - val_accuracy: 0.8724 - val_loss: 0.4873 - learning_rate: 0.0100
# Epoch 22/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 102s 131ms/step - accuracy: 0.9641 - loss: 0.1206 - val_accuracy: 0.8677 - val_loss: 0.5079 - learning_rate: 0.0100
# Epoch 23/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 102s 130ms/step - accuracy: 0.9657 - loss: 0.1176 - val_accuracy: 0.8463 - val_loss: 0.6001 - learning_rate: 0.0100
# Epoch 24/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 105s 135ms/step - accuracy: 0.9653 - loss: 0.1186 - val_accuracy: 0.8768 - val_loss: 0.4710 - learning_rate: 0.0100
# Epoch 25/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 103s 131ms/step - accuracy: 0.9681 - loss: 0.1089 - val_accuracy: 0.8754 - val_loss: 0.4962 - learning_rate: 0.0100
# Epoch 26/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 104s 132ms/step - accuracy: 0.9710 - loss: 0.1043 - val_accuracy: 0.8721 - val_loss: 0.5287 - learning_rate: 0.0100
# Epoch 27/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 103s 131ms/step - accuracy: 0.9727 - loss: 0.1001 - val_accuracy: 0.8665 - val_loss: 0.5430 - learning_rate: 0.0100
# Epoch 28/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.9762 - loss: 0.0875
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.0009999999776482583.
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 102s 131ms/step - accuracy: 0.9762 - loss: 0.0875 - val_accuracy: 0.8762 - val_loss: 0.5414 - learning_rate: 0.0100
# Epoch 29/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 106s 135ms/step - accuracy: 0.9828 - loss: 0.0709 - val_accuracy: 0.8978 - val_loss: 0.4423 - learning_rate: 1.0000e-03
# Epoch 30/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 102s 131ms/step - accuracy: 0.9895 - loss: 0.0499 - val_accuracy: 0.8973 - val_loss: 0.4585 - learning_rate: 1.0000e-03
# Epoch 31/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 106s 136ms/step - accuracy: 0.9925 - loss: 0.0415 - val_accuracy: 0.9016 - val_loss: 0.4466 - learning_rate: 1.0000e-03
# Epoch 32/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 102s 131ms/step - accuracy: 0.9935 - loss: 0.0397 - val_accuracy: 0.9004 - val_loss: 0.4595 - learning_rate: 1.0000e-03
# Epoch 33/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 106s 135ms/step - accuracy: 0.9936 - loss: 0.0378 - val_accuracy: 0.9021 - val_loss: 0.4597 - learning_rate: 1.0000e-03
# Epoch 34/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 103s 131ms/step - accuracy: 0.9951 - loss: 0.0346 - val_accuracy: 0.9017 - val_loss: 0.4668 - learning_rate: 1.0000e-03
# Epoch 35/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 102s 131ms/step - accuracy: 0.9951 - loss: 0.0332 - val_accuracy: 0.8998 - val_loss: 0.4790 - learning_rate: 1.0000e-03
# Epoch 36/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 102s 131ms/step - accuracy: 0.9952 - loss: 0.0339 - val_accuracy: 0.9014 - val_loss: 0.4755 - learning_rate: 1.0000e-03
# Epoch 37/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 102s 131ms/step - accuracy: 0.9957 - loss: 0.0312 - val_accuracy: 0.9014 - val_loss: 0.4830 - learning_rate: 1.0000e-03
# Epoch 38/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 106s 136ms/step - accuracy: 0.9957 - loss: 0.0320 - val_accuracy: 0.9027 - val_loss: 0.4753 - learning_rate: 1.0000e-03
# Epoch 39/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.9966 - loss: 0.0304
# Epoch 39: ReduceLROnPlateau reducing learning rate to 9.999999310821295e-05.
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 106s 135ms/step - accuracy: 0.9966 - loss: 0.0304 - val_accuracy: 0.9028 - val_loss: 0.4782 - learning_rate: 1.0000e-03
# Epoch 40/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 106s 135ms/step - accuracy: 0.9968 - loss: 0.0288 - val_accuracy: 0.9031 - val_loss: 0.4743 - learning_rate: 1.0000e-04
# Epoch 41/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 103s 131ms/step - accuracy: 0.9966 - loss: 0.0297 - val_accuracy: 0.9022 - val_loss: 0.4764 - learning_rate: 1.0000e-04
# Epoch 42/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 103s 132ms/step - accuracy: 0.9963 - loss: 0.0300 - val_accuracy: 0.9028 - val_loss: 0.4766 - learning_rate: 1.0000e-04
# Epoch 43/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 107s 137ms/step - accuracy: 0.9963 - loss: 0.0300 - val_accuracy: 0.9034 - val_loss: 0.4755 - learning_rate: 1.0000e-04
# Epoch 44/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 104s 132ms/step - accuracy: 0.9966 - loss: 0.0287 - val_accuracy: 0.9029 - val_loss: 0.4773 - learning_rate: 1.0000e-04
# Epoch 45/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 103s 132ms/step - accuracy: 0.9959 - loss: 0.0305 - val_accuracy: 0.9028 - val_loss: 0.4803 - learning_rate: 1.0000e-04
# Epoch 46/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 103s 131ms/step - accuracy: 0.9970 - loss: 0.0288 - val_accuracy: 0.9028 - val_loss: 0.4791 - learning_rate: 1.0000e-04
# Epoch 47/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 103s 132ms/step - accuracy: 0.9968 - loss: 0.0296 - val_accuracy: 0.9031 - val_loss: 0.4774 - learning_rate: 1.0000e-04
# Epoch 48/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 108s 138ms/step - accuracy: 0.9965 - loss: 0.0290 - val_accuracy: 0.9035 - val_loss: 0.4779 - learning_rate: 1.0000e-04
# Epoch 49/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9971 - loss: 0.0286
# Epoch 49: ReduceLROnPlateau reducing learning rate to 1e-05.
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 107s 137ms/step - accuracy: 0.9971 - loss: 0.0286 - val_accuracy: 0.9041 - val_loss: 0.4758 - learning_rate: 1.0000e-04
# Epoch 50/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 107s 136ms/step - accuracy: 0.9967 - loss: 0.0285 - val_accuracy: 0.9042 - val_loss: 0.4753 - learning_rate: 1.0000e-05
# Epoch 51/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 107s 137ms/step - accuracy: 0.9971 - loss: 0.0283 - val_accuracy: 0.9043 - val_loss: 0.4748 - learning_rate: 1.0000e-05
# Epoch 52/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 107s 137ms/step - accuracy: 0.9969 - loss: 0.0286 - val_accuracy: 0.9044 - val_loss: 0.4756 - learning_rate: 1.0000e-05
# Epoch 53/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 104s 132ms/step - accuracy: 0.9968 - loss: 0.0293 - val_accuracy: 0.9042 - val_loss: 0.4764 - learning_rate: 1.0000e-05
# Epoch 54/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 104s 132ms/step - accuracy: 0.9968 - loss: 0.0296 - val_accuracy: 0.9044 - val_loss: 0.4762 - learning_rate: 1.0000e-05
# Epoch 55/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 103s 132ms/step - accuracy: 0.9976 - loss: 0.0278 - val_accuracy: 0.9044 - val_loss: 0.4758 - learning_rate: 1.0000e-05
# Epoch 56/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 103s 132ms/step - accuracy: 0.9970 - loss: 0.0287 - val_accuracy: 0.9040 - val_loss: 0.4763 - learning_rate: 1.0000e-05
# Epoch 57/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 107s 137ms/step - accuracy: 0.9972 - loss: 0.0272 - val_accuracy: 0.9046 - val_loss: 0.4764 - learning_rate: 1.0000e-05
# Epoch 58/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 104s 133ms/step - accuracy: 0.9978 - loss: 0.0267 - val_accuracy: 0.9042 - val_loss: 0.4769 - learning_rate: 1.0000e-05
# Epoch 59/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 104s 132ms/step - accuracy: 0.9973 - loss: 0.0279 - val_accuracy: 0.9042 - val_loss: 0.4771 - learning_rate: 1.0000e-05
# Epoch 60/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 103s 132ms/step - accuracy: 0.9978 - loss: 0.0268 - val_accuracy: 0.9042 - val_loss: 0.4773 - learning_rate: 1.0000e-05
# Epoch 61/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 103s 132ms/step - accuracy: 0.9972 - loss: 0.0287 - val_accuracy: 0.9042 - val_loss: 0.4767 - learning_rate: 1.0000e-05
# Epoch 62/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 104s 132ms/step - accuracy: 0.9967 - loss: 0.0291 - val_accuracy: 0.9040 - val_loss: 0.4767 - learning_rate: 1.0000e-05
# Epoch 63/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 104s 132ms/step - accuracy: 0.9972 - loss: 0.0281 - val_accuracy: 0.9040 - val_loss: 0.4775 - learning_rate: 1.0000e-05
# Epoch 64/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 103s 132ms/step - accuracy: 0.9964 - loss: 0.0299 - val_accuracy: 0.9037 - val_loss: 0.4776 - learning_rate: 1.0000e-05
# Epoch 65/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 104s 133ms/step - accuracy: 0.9972 - loss: 0.0277 - val_accuracy: 0.9037 - val_loss: 0.4782 - learning_rate: 1.0000e-05
# Epoch 66/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 103s 132ms/step - accuracy: 0.9967 - loss: 0.0285 - val_accuracy: 0.9042 - val_loss: 0.4775 - learning_rate: 1.0000e-05
# Epoch 67/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 103s 132ms/step - accuracy: 0.9973 - loss: 0.0281 - val_accuracy: 0.9037 - val_loss: 0.4786 - learning_rate: 1.0000e-05
# Epoch 68/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 104s 132ms/step - accuracy: 0.9969 - loss: 0.0294 - val_accuracy: 0.9035 - val_loss: 0.4790 - learning_rate: 1.0000e-05
# Epoch 69/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 103s 132ms/step - accuracy: 0.9975 - loss: 0.0275 - val_accuracy: 0.9042 - val_loss: 0.4782 - learning_rate: 1.0000e-05
# Epoch 70/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 104s 132ms/step - accuracy: 0.9974 - loss: 0.0278 - val_accuracy: 0.9042 - val_loss: 0.4779 - learning_rate: 1.0000e-05
# Epoch 71/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 104s 133ms/step - accuracy: 0.9975 - loss: 0.0279 - val_accuracy: 0.9041 - val_loss: 0.4789 - learning_rate: 1.0000e-05
# Epoch 72/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 104s 133ms/step - accuracy: 0.9969 - loss: 0.0284 - val_accuracy: 0.9044 - val_loss: 0.4787 - learning_rate: 1.0000e-05
# Epoch 73/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 104s 133ms/step - accuracy: 0.9973 - loss: 0.0279 - val_accuracy: 0.9037 - val_loss: 0.4790 - learning_rate: 1.0000e-05
# Epoch 74/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 104s 132ms/step - accuracy: 0.9967 - loss: 0.0289 - val_accuracy: 0.9040 - val_loss: 0.4792 - learning_rate: 1.0000e-05
# Epoch 75/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 104s 133ms/step - accuracy: 0.9974 - loss: 0.0275 - val_accuracy: 0.9040 - val_loss: 0.4782 - learning_rate: 1.0000e-05
# Epoch 76/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 104s 132ms/step - accuracy: 0.9963 - loss: 0.0289 - val_accuracy: 0.9042 - val_loss: 0.4776 - learning_rate: 1.0000e-05
# Epoch 77/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 104s 133ms/step - accuracy: 0.9970 - loss: 0.0289 - val_accuracy: 0.9040 - val_loss: 0.4779 - learning_rate: 1.0000e-05
# Final val_acc (official test): 0.904

# %% [markdown]
# ### Evaluate on official test (your Kaggle score estimate)

# %%
loss, acc = model.evaluate(test_ds, verbose=0)
print("Official CIFAR-10 test accuracy (Kaggle-score estimate):", round(float(acc), 4))
# Out:
# Official CIFAR-10 test accuracy (Kaggle-score estimate): 0.9046

# %% [markdown]
# ### locate & extract test.7z

# %%
import py7zr, os, glob

input_dir = "/kaggle/input/cifar-10"
test_7z = os.path.join(input_dir, "test.7z")

if os.path.exists(test_7z):
    with py7zr.SevenZipFile(test_7z, mode='r') as z:
        z.extractall(path=".")
    print("Extracted test images:", len(glob.glob("test/*.png")))
else:
    print("test.7z not found at", test_7z)
# Out:
# Extracted test images: 300000

# %% [markdown]
# ### Build submission.csv

# %%
from PIL import Image

def load_png(fp):
    im = Image.open(fp).convert("RGB")
    # Should already be 32x32; resize defensively just in case
    im = im.resize((32,32), resample=Image.BILINEAR)
    arr = np.asarray(im).astype(np.float32) / 255.0
    return arr

test_files = sorted(glob.glob("test/*.png"), key=lambda p: int(os.path.splitext(os.path.basename(p))[0]))

BATCH = 1024
pred_labels = []
for i in range(0, len(test_files), BATCH):
    batch_files = test_files[i:i+BATCH]
    batch = np.stack([load_png(f) for f in batch_files], axis=0)
    probs = model.predict(batch, verbose=0)
    idx  = np.argmax(probs, axis=1)
    pred_labels.extend([CLASS_NAMES[j] for j in idx])

ids = [int(os.path.splitext(os.path.basename(f))[0]) for f in test_files]
sub = pd.DataFrame({"id": ids, "label": pred_labels})
sub.to_csv("submission.csv", index=False)
sub.head()
# Out:
#    id       label
# 0   1  automobile
# 1   2    airplane
# 2   3  automobile
# 3   4        ship
# 4   5        bird

# %% [markdown]
# ### quick sanity checks on submission

# %%
# Check format and label set
assert set(sub.columns)=={"id","label"}
assert set(sub["label"].unique()).issubset(set(CLASSES))
assert sub["id"].min()==1 and sub["id"].max()==300000 and len(sub)==300000
print("Submission looks well-formed:", sub.shape, "rows")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_19/1158000592.py in <cell line: 0>()
#       1 # Check format and label set
#       2 assert set(sub.columns)=={"id","label"}
# ----> 3 assert set(sub["label"].unique()).issubset(set(CLASSES))
#       4 assert sub["id"].min()==1 and sub["id"].max()==300000 and len(sub)==300000
#       5 print("Submission looks well-formed:", sub.shape, "rows")
#
# NameError: name 'CLASSES' is not defined
